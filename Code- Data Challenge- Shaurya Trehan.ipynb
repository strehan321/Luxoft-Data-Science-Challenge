# %% [markdown]
# # Data Challenge- (Road Safety Data for Year 2013)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Casualty Data

# %%
casualty = pd.read_csv("C:/Luxoft/2013/Casualties_2013.csv")

# %%
casualty.head()
# Out:
#        Acc_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  201301BS70003                  2                   1               1
# 1  201301BS70005                  1                   1               1
# 2  201301BS70005                  1                   2               3
# 3  201301BS70006                  1                   1               2
# 4  201301BS70007                  1                   1               1
#
#    Sex_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                1                     7                  2
# 1                2                     6                  3
# 2                2                     4                  3
# 3                1                    10                  3
# 4                1                     7                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# 0                    0                    0              0
# ...

# %%
casualty.shape
# Out:
# (183670, 14)

# %%
casualty.describe()
# Out:
#        Vehicle_Reference  Casualty_Reference  Casualty_Class  Sex_of_Casualty  \
# count      183670.000000       183670.000000   183670.000000    183670.000000
# mean            1.499211            1.422072        1.487260         1.410650
# std             0.950871            2.420165        0.715219         0.492318
# min             1.000000            1.000000        1.000000        -1.000000
# 25%             1.000000            1.000000        1.000000         1.000000
# 50%             1.000000            1.000000        1.000000         1.000000
# 75%             2.000000            2.000000        2.000000         2.000000
# max            67.000000          852.000000        3.000000         2.000000
#
#        Age_Band_of_Casualty  Casualty_Severity  Pedestrian_Location  \
# count         183670.000000      183670.000000        183670.000000
# mean               6.214003           2.863434             0.693189
# ...

# %%
casualty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183670 entries, 0 to 183669
# Data columns (total 14 columns):
# Acc_Index                             183670 non-null object
# Vehicle_Reference                     183670 non-null int64
# Casualty_Reference                    183670 non-null int64
# Casualty_Class                        183670 non-null int64
# Sex_of_Casualty                       183670 non-null int64
# Age_Band_of_Casualty                  183670 non-null int64
# Casualty_Severity                     183670 non-null int64
# Pedestrian_Location                   183670 non-null int64
# Pedestrian_Movement                   183670 non-null int64
# Car_Passenger                         183670 non-null int64
# Bus_or_Coach_Passenger                183670 non-null int64
# Pedestrian_Road_Maintenance_Worker    183670 non-null int64
# Casualty_Type                         183670 non-null int64
# Casualty_Home_Area_Type               183670 non-null int64
# ...

# %% [markdown]
# ### Checking for Null Values

# %%
pd.isnull(casualty).sum()
# Out:
# Acc_Index                             0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# dtype: int64

# %% [markdown]
# ### Reading Vehicle Data

# %%
vehicle = pd.read_csv("C:/Luxoft/2013/Vehicles by Make and Model 2013.csv")

# %%
vehicle.head()
# Out:
#        Acc_Index  accyr  Vehicle_Reference  Vehicle_Type  \
# 0  201301BS70003   2013                  1             8
# 1  201301BS70005   2013                  1             3
# 2  201301BS70006   2013                  1            11
# 3  201301BS70007   2013                  1             3
# 4  201301BS70007   2013                  2             9
#
#    Towing_and_Articulation  Vehicle_Manoeuvre  \
# 0                        0                  6
# 1                        0                 18
# 2                        0                 14
# 3                        0                  4
# 4                        0                 18
#
#    Vehicle_Location-Restricted_Lane  Junction_Location  \
# 0                                 0                  2
# 1                                 0                  1
# 2                                 0                  1
# 3                                 0                  8
# 4                                 0                  8
#
# ...

# %%
vehicle.shape
# Out:
# (171625, 24)

# %% [markdown]
# ### Checking for Null Values

# %%
pd.isnull(vehicle).sum()
# Out:
# Acc_Index                           0
# accyr                               0
# Vehicle_Reference                   0
# Vehicle_Type                        0
# Towing_and_Articulation             0
# Vehicle_Manoeuvre                   0
# Vehicle_Location-Restricted_Lane    0
# Junction_Location                   0
# Skidding_and_Overturning            0
# Hit_Object_in_Carriageway           0
# Vehicle_Leaving_Carriageway         0
# Hit_Object_off_Carriageway          0
# 1st_Point_of_Impact                 0
# Was_Vehicle_Left_Hand_Drive         0
# Journey_Purpose_of_Driver           0
# Sex_of_Driver                       0
# Age_Band_of_Driver                  0
# Engine_Capacity_(CC)                0
# Propulsion_Code                     0
# Age_of_Vehicle                      0
# Driver_IMD_Decile                   0
# Driver_Home_Area_Type               0
# make                                0
# model                               0
# dtype: int64

# %%
vehicle.describe()
# Out:
#           accyr  Vehicle_Reference   Vehicle_Type  Towing_and_Articulation  \
# count  171625.0      171625.000000  171625.000000            171625.000000
# mean     2013.0           1.552076       9.949133                 0.029937
# std         0.0           0.988286       6.525528                 0.301511
# min      2013.0           1.000000       1.000000                -1.000000
# 25%      2013.0           1.000000       9.000000                 0.000000
# 50%      2013.0           1.000000       9.000000                 0.000000
# 75%      2013.0           2.000000       9.000000                 0.000000
# max      2013.0          66.000000      98.000000                 5.000000
#
#        Vehicle_Manoeuvre  Vehicle_Location-Restricted_Lane  Junction_Location  \
# count      171625.000000                      171625.00000      171625.000000
# mean           12.248991                           0.09639           2.612556
# ...

# %%
vehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171625 entries, 0 to 171624
# Data columns (total 24 columns):
# Acc_Index                           171625 non-null object
# accyr                               171625 non-null int64
# Vehicle_Reference                   171625 non-null int64
# Vehicle_Type                        171625 non-null int64
# Towing_and_Articulation             171625 non-null int64
# Vehicle_Manoeuvre                   171625 non-null int64
# Vehicle_Location-Restricted_Lane    171625 non-null int64
# Junction_Location                   171625 non-null int64
# Skidding_and_Overturning            171625 non-null int64
# Hit_Object_in_Carriageway           171625 non-null int64
# Vehicle_Leaving_Carriageway         171625 non-null int64
# Hit_Object_off_Carriageway          171625 non-null int64
# 1st_Point_of_Impact                 171625 non-null int64
# Was_Vehicle_Left_Hand_Drive         171625 non-null int64
# ...

# %% [markdown]
# ### Joining Vehicle and Casualty Data

# %%
vehcas = pd.merge(casualty, vehicle)

# %%
vehcas.head()
# Out:
#        Acc_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  201301BS70005                  1                   1               1
# 1  201301BS70005                  1                   2               3
# 2  201301BS70006                  1                   1               2
# 3  201301BS70007                  1                   1               1
# 4  201301BS70009                  1                   1               1
#
#    Sex_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                2                     6                  3
# 1                2                     4                  3
# 2                1                    10                  3
# 3                1                     7                  3
# 4                1                     6                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# 0                    0                    0              0
# ...

# %%
vehcas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123707 entries, 0 to 123706
# Data columns (total 36 columns):
# Acc_Index                             123707 non-null object
# Vehicle_Reference                     123707 non-null int64
# Casualty_Reference                    123707 non-null int64
# Casualty_Class                        123707 non-null int64
# Sex_of_Casualty                       123707 non-null int64
# Age_Band_of_Casualty                  123707 non-null int64
# Casualty_Severity                     123707 non-null int64
# Pedestrian_Location                   123707 non-null int64
# Pedestrian_Movement                   123707 non-null int64
# Car_Passenger                         123707 non-null int64
# Bus_or_Coach_Passenger                123707 non-null int64
# Pedestrian_Road_Maintenance_Worker    123707 non-null int64
# Casualty_Type                         123707 non-null int64
# Casualty_Home_Area_Type               123707 non-null int64
# ...

# %%
pd.isnull(vehcas).sum()
# Out:
# Acc_Index                             0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# accyr                                 0
# Vehicle_Type                          0
# Towing_and_Articulation               0
# Vehicle_Manoeuvre                     0
# Vehicle_Location-Restricted_Lane      0
# Junction_Location                     0
# Skidding_and_Overturning              0
# Hit_Object_in_Carriageway             0
# Vehicle_Leaving_Carriageway           0
# ...

# %%
vehcas.shape
# Out:
# (123707, 36)

# %% [markdown]
# ### Reading Accident Data

# %%
accident = pd.read_csv("C:/Luxoft/2013/Accidents_2013.csv", low_memory=False)

# %%
accident.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201301BS70003                 527060                  177970  -0.171402
# 1  201301BS70005                 526900                  178940  -0.173356
# 2  201301BS70006                 524240                  181460  -0.210767
# 3  201301BS70007                 524320                  181290  -0.209675
# 4  201301BS70009                 525450                  178660  -0.194332
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.486361             1                  2                   2
# 1  51.495115             1                  3                   1
# 2  51.518353             1                  3                   1
# 3  51.516808             1                  3                   2
# 4  51.492922             1                  3                   2
#
#    Number_of_Casualties        Date            ...              \
# ...

# %%
accident.shape
# Out:
# (138660, 32)

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138660 entries, 0 to 138659
# Data columns (total 32 columns):
# Accident_Index                                 138660 non-null object
# Location_Easting_OSGR                          138660 non-null int64
# Location_Northing_OSGR                         138660 non-null int64
# Longitude                                      138660 non-null float64
# Latitude                                       138660 non-null float64
# Police_Force                                   138660 non-null int64
# Accident_Severity                              138660 non-null int64
# Number_of_Vehicles                             138660 non-null int64
# Number_of_Casualties                           138660 non-null int64
# Date                                           138660 non-null object
# Day_of_Week                                    138660 non-null int64
# Time                                           138652 non-null object
# ...

# %% [markdown]
# ### Dropping Rows with Null Values

# %%
accidents = accident.dropna(axis=0)
pd.isnull(accidents).sum()
# Out:
# Accident_Index                                 0
# Location_Easting_OSGR                          0
# Location_Northing_OSGR                         0
# Longitude                                      0
# Latitude                                       0
# Police_Force                                   0
# Accident_Severity                              0
# Number_of_Vehicles                             0
# Number_of_Casualties                           0
# Date                                           0
# Day_of_Week                                    0
# Time                                           0
# Local_Authority_(District)                     0
# Local_Authority_(Highway)                      0
# 1st_Road_Class                                 0
# 1st_Road_Number                                0
# Road_Type                                      0
# Speed_limit                                    0
# Junction_Detail                                0
# ...

# %% [markdown]
# ### Combining Accidents Data with combination of Vehicle and Casualty Data

# %%
master= pd.merge(vehcas, accidents, left_on="Acc_Index", right_on="Accident_Index", how='inner')

# %%
master.head()
# Out:
#        Acc_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  201301BS70005                  1                   1               1
# 1  201301BS70005                  1                   2               3
# 2  201301BS70006                  1                   1               2
# 3  201301BS70007                  1                   1               1
# 4  201301BS70009                  1                   1               1
#
#    Sex_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                2                     6                  3
# 1                2                     4                  3
# 2                1                    10                  3
# 3                1                     7                  3
# 4                1                     6                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# 0                    0                    0              0
# ...

# %%
master.shape
# Out:
# (114564, 68)

# %%
master.columns
# Out:
# Index(['Acc_Index', 'Vehicle_Reference', 'Casualty_Reference',
#        'Casualty_Class', 'Sex_of_Casualty', 'Age_Band_of_Casualty',
#        'Casualty_Severity', 'Pedestrian_Location', 'Pedestrian_Movement',
#        'Car_Passenger', 'Bus_or_Coach_Passenger',
#        'Pedestrian_Road_Maintenance_Worker', 'Casualty_Type',
#        'Casualty_Home_Area_Type', 'accyr', 'Vehicle_Type',
#        'Towing_and_Articulation', 'Vehicle_Manoeuvre',
#        'Vehicle_Location-Restricted_Lane', 'Junction_Location',
#        'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
#        'Vehicle_Leaving_Carriageway', 'Hit_Object_off_Carriageway',
#        '1st_Point_of_Impact', 'Was_Vehicle_Left_Hand_Drive',
#        'Journey_Purpose_of_Driver', 'Sex_of_Driver', 'Age_Band_of_Driver',
#        'Engine_Capacity_(CC)', 'Propulsion_Code', 'Age_of_Vehicle',
#        'Driver_IMD_Decile', 'Driver_Home_Area_Type', 'make', 'model',
# ...

# %%
#master.info()

# %% [markdown]
# ### Substituting "-1" with Null values

# %%
data =master.replace(to_replace=-1, value= np.nan)

# %%
data.shape
# Out:
# (114564, 68)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114564 entries, 0 to 114563
# Data columns (total 68 columns):
# Acc_Index                                      114564 non-null object
# Vehicle_Reference                              114564 non-null int64
# Casualty_Reference                             114564 non-null int64
# Casualty_Class                                 114564 non-null int64
# Sex_of_Casualty                                114564 non-null int64
# Age_Band_of_Casualty                           112708 non-null float64
# Casualty_Severity                              114564 non-null int64
# Pedestrian_Location                            114564 non-null int64
# Pedestrian_Movement                            114564 non-null int64
# Car_Passenger                                  114308 non-null float64
# Bus_or_Coach_Passenger                         114541 non-null float64
# Pedestrian_Road_Maintenance_Worker             114550 non-null float64
# ...

# %%
def missing_values_table(data): 
        mis_val = data.isnull().sum()
        mis_val_percent = 100 * data.isnull().sum() / len(data)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        return mis_val_table_ren_columns
missing_values_table(data)
# Out:
#                                              Missing Values  % of Total Values
# Acc_Index                                                 0           0.000000
# Vehicle_Reference                                         0           0.000000
# Casualty_Reference                                        0           0.000000
# Casualty_Class                                            0           0.000000
# Sex_of_Casualty                                           0           0.000000
# Age_Band_of_Casualty                                   1856           1.620055
# Casualty_Severity                                         0           0.000000
# Pedestrian_Location                                       0           0.000000
# Pedestrian_Movement                                       0           0.000000
# Car_Passenger                                           256           0.223456
# Bus_or_Coach_Passenger                                   23           0.020076
# ...

# %% [markdown]
# ### Removing Features with more than 40% Null Values

# %%
data1 = data.drop(columns=["Junction_Control", "2nd_Road_Class"])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114564 entries, 0 to 114563
# Data columns (total 66 columns):
# Acc_Index                                      114564 non-null object
# Vehicle_Reference                              114564 non-null int64
# Casualty_Reference                             114564 non-null int64
# Casualty_Class                                 114564 non-null int64
# Sex_of_Casualty                                114564 non-null int64
# Age_Band_of_Casualty                           112708 non-null float64
# Casualty_Severity                              114564 non-null int64
# Pedestrian_Location                            114564 non-null int64
# Pedestrian_Movement                            114564 non-null int64
# Car_Passenger                                  114308 non-null float64
# Bus_or_Coach_Passenger                         114541 non-null float64
# Pedestrian_Road_Maintenance_Worker             114550 non-null float64
# ...

# %%
pd.isnull(data1).sum()
# Out:
# Acc_Index                                          0
# Vehicle_Reference                                  0
# Casualty_Reference                                 0
# Casualty_Class                                     0
# Sex_of_Casualty                                    0
# Age_Band_of_Casualty                            1856
# Casualty_Severity                                  0
# Pedestrian_Location                                0
# Pedestrian_Movement                                0
# Car_Passenger                                    256
# Bus_or_Coach_Passenger                            23
# Pedestrian_Road_Maintenance_Worker                14
# Casualty_Type                                      0
# Casualty_Home_Area_Type                        11420
# accyr                                              0
# Vehicle_Type                                       0
# Towing_and_Articulation                            1
# Vehicle_Manoeuvre                                  4
# ...

# %%
data1.shape
# Out:
# (114564, 66)

# %% [markdown]
# ### Imputing Missing Values(Continuous Variables with mean) and Discrete Variables with Median for features having more than 10% missing values

# %%
data1['Age_of_Vehicle'] = data1['Age_of_Vehicle'].fillna((data1['Age_of_Vehicle'].mean()))
data1['Driver_IMD_Decile'] = data1['Driver_IMD_Decile'].fillna((data1['Driver_IMD_Decile'].mean()))
data1['Casualty_Home_Area_Type'] = data1['Casualty_Home_Area_Type'].fillna((data1['Casualty_Home_Area_Type'].median()))

# %% [markdown]
# ### Dropping rows with minimal missing values

# %%
data2 = data1.dropna(axis=0)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97612 entries, 0 to 114563
# Data columns (total 66 columns):
# Acc_Index                                      97612 non-null object
# Vehicle_Reference                              97612 non-null int64
# Casualty_Reference                             97612 non-null int64
# Casualty_Class                                 97612 non-null int64
# Sex_of_Casualty                                97612 non-null int64
# Age_Band_of_Casualty                           97612 non-null float64
# Casualty_Severity                              97612 non-null int64
# Pedestrian_Location                            97612 non-null int64
# Pedestrian_Movement                            97612 non-null int64
# Car_Passenger                                  97612 non-null float64
# Bus_or_Coach_Passenger                         97612 non-null float64
# Pedestrian_Road_Maintenance_Worker             97612 non-null float64
# ...

# %%
data2.describe()
# Out:
#        Vehicle_Reference  Casualty_Reference  Casualty_Class  Sex_of_Casualty  \
# count       97612.000000        97612.000000    97612.000000     97612.000000
# mean            1.497879            1.492101        1.480084         1.452055
# std             0.969717            3.066362        0.691955         0.497699
# min             1.000000            1.000000        1.000000         1.000000
# 25%             1.000000            1.000000        1.000000         1.000000
# 50%             1.000000            1.000000        1.000000         1.000000
# 75%             2.000000            2.000000        2.000000         2.000000
# max            64.000000          852.000000        3.000000         2.000000
#
#        Age_Band_of_Casualty  Casualty_Severity  Pedestrian_Location  \
# count          97612.000000       97612.000000         97612.000000
# mean               6.416957           2.874257             0.593728
# ...

# %%
data2.shape
# Out:
# (97612, 66)

# %%
# No of accidents

# %%
data2["Acc_Index"].nunique()
# Out:
# 73033

# %%
data2.columns
# Out:
# Index(['Acc_Index', 'Vehicle_Reference', 'Casualty_Reference',
#        'Casualty_Class', 'Sex_of_Casualty', 'Age_Band_of_Casualty',
#        'Casualty_Severity', 'Pedestrian_Location', 'Pedestrian_Movement',
#        'Car_Passenger', 'Bus_or_Coach_Passenger',
#        'Pedestrian_Road_Maintenance_Worker', 'Casualty_Type',
#        'Casualty_Home_Area_Type', 'accyr', 'Vehicle_Type',
#        'Towing_and_Articulation', 'Vehicle_Manoeuvre',
#        'Vehicle_Location-Restricted_Lane', 'Junction_Location',
#        'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
#        'Vehicle_Leaving_Carriageway', 'Hit_Object_off_Carriageway',
#        '1st_Point_of_Impact', 'Was_Vehicle_Left_Hand_Drive',
#        'Journey_Purpose_of_Driver', 'Sex_of_Driver', 'Age_Band_of_Driver',
#        'Engine_Capacity_(CC)', 'Propulsion_Code', 'Age_of_Vehicle',
#        'Driver_IMD_Decile', 'Driver_Home_Area_Type', 'make', 'model',
# ...

# %% [markdown]
# ### Creating New Variable "Time of Day"

# %%
data2['Time_of_Day']= np.where(data2['Time']<"07:00", "Early Morning", 
                               np.where(data2['Time']<"18:00", "Office Hours", "Evening"))
# Out:
# c:\users\shaur\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2['Time_of_Day'].head()
# Out:
# 0    Office Hours
# 1    Office Hours
# 3    Office Hours
# 4    Office Hours
# 6    Office Hours
# Name: Time_of_Day, dtype: object

# %%
data2['Time_of_Day'].value_counts()
# Out:
# Office Hours     67953
# Evening          22858
# Early Morning     6801
# Name: Time_of_Day, dtype: int64

# %% [markdown]
# ### Pie Chart of Accidents by Time of Day

# %%
plt.pie(data2['Time_of_Day'].value_counts(), labels=["Office Hours", "Evening", "Early Morning"])
# Out:
# ([<matplotlib.patches.Wedge at 0x15b4b3ea8d0>,
# ...
#  [Text(-0.635765,0.897665,'Office Hours'),
#   Text(0.425674,-1.0143,'Evening'),
#   Text(1.07375,-0.238857,'Early Morning')])

# %% [markdown]
# ### Label Encoding Required For Machine Learning Model

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
data2['Time_of_Day'] = LE.fit_transform(data2['Time_of_Day'])
# Out:
# c:\users\shaur\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Exporting Master Data File for further use(Data Visualization)

# %%
data2.to_csv("final.csv")

# %% [markdown]
# ### Data Preparation for Predictive Machine Learning Models

# %%
y1= data2['Number_of_Casualties']

# %%
y1.shape
# Out:
# (97612,)

# %% [markdown]
# #### Dropping Irrelevant Columns

# %%
X1 = data2.drop(data2.columns[[0,1,2,14,34,35,36,37,38,39,40,44,45,47, 49, 65]], axis=1)

# %%
X1.shape
# Out:
# (97612, 51)

# %%
X1.columns
# Out:
# Index(['Casualty_Class', 'Sex_of_Casualty', 'Age_Band_of_Casualty',
#        'Casualty_Severity', 'Pedestrian_Location', 'Pedestrian_Movement',
#        'Car_Passenger', 'Bus_or_Coach_Passenger',
#        'Pedestrian_Road_Maintenance_Worker', 'Casualty_Type',
#        'Casualty_Home_Area_Type', 'Vehicle_Type', 'Towing_and_Articulation',
#        'Vehicle_Manoeuvre', 'Vehicle_Location-Restricted_Lane',
#        'Junction_Location', 'Skidding_and_Overturning',
#        'Hit_Object_in_Carriageway', 'Vehicle_Leaving_Carriageway',
#        'Hit_Object_off_Carriageway', '1st_Point_of_Impact',
#        'Was_Vehicle_Left_Hand_Drive', 'Journey_Purpose_of_Driver',
#        'Sex_of_Driver', 'Age_Band_of_Driver', 'Engine_Capacity_(CC)',
#        'Propulsion_Code', 'Age_of_Vehicle', 'Driver_IMD_Decile',
#        'Driver_Home_Area_Type', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Day_of_Week', 'Local_Authority_(District)',
# ...

# %% [markdown]
# ### Splitting Data

# %%
from sklearn.model_selection import train_test_split
X_train_org, X_test_org, y_train, y_test = train_test_split(X1,y1, test_size = 0.25, random_state = 10)
print("X1 Train Shape : {}".format(X_train_org.shape))
print("X1 Test Shape : {}".format(X_test_org.shape))
print("y1 Train Shape : {}".format(y_train.shape))
print("y1 Test Shape : {}".format(y_test.shape))
# Out:
# X1 Train Shape : (73209, 51)
# X1 Test Shape : (24403, 51)
# y1 Train Shape : (73209,)
# y1 Test Shape : (24403,)

# %%
X_train_org.head()
# Out:
#        Casualty_Class  Sex_of_Casualty  Age_Band_of_Casualty  \
# 63214               1                2                   8.0
# 66291               3                1                   9.0
# 29725               2                1                   4.0
# 97045               1                1                  10.0
# 55063               1                1                   6.0
#
#        Casualty_Severity  Pedestrian_Location  Pedestrian_Movement  \
# 63214                  3                    0                    0
# 66291                  3                    2                    4
# 29725                  3                    0                    0
# 97045                  3                    0                    0
# 55063                  3                    0                    0
#
#        Car_Passenger  Bus_or_Coach_Passenger  \
# 63214            0.0                     0.0
# 66291            0.0                     0.0
# 29725            1.0                     0.0
# ...

# %% [markdown]
# ## Random Forest Ensemble to find important features

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=10, n_jobs=-1).fit(X_train_org, y_train)

print("R2 score from training set :"+str(rf.score(X_train_org,y_train)))

print("R2 score from test set :"+str(rf.score(X_test_org,y_test)))
# Out:
# R2 score from training set :0.964387952209
# R2 score from test set :0.766009318782

# %% [markdown]
# #### Very High Training Accuracy and lower test accuracy. This model is overfitting

# %% [markdown]
# ## Parameter Tuning (Grid Search with Cross Validation)

# %%
# param_grid = {'max_features': [10,20,30,40,50],
#            'max_depth': [2,4,6,8,10]}
# rf = RandomForestRegressor(random_state=10, n_jobs=-1)
# grid_search = GridSearchCV(rf,param_grid,cv=5)
# grid_search.fit(X_train, y_train)
# grid_search.best_params_

# %%
rf = RandomForestRegressor(max_features=40, max_depth=10,random_state=10).fit(X_train_org, y_train)
print('Accuracy of RF Regressor on training set: {:.2f}'
     .format(rf.score(X_train_org, y_train)))
print('Accuracy of Rf Regressor on test set: {:.2f}'
     .format(rf.score(X_test_org, y_test)))
# Out:
# Accuracy of RF Regressor on training set: 0.83
# Accuracy of Rf Regressor on test set: 0.77

# %% [markdown]
# ### This is a better optimized result with more regularization (Controlling overfitting) and higher test score

# %% [markdown]
# ### <font color="red"> Plot Important Features

# %%
features=X1.columns
importances = rf.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(25,15))
plt.title('Feature Importances', size=30)
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features[indices])
plt.xlabel('Relative Importance')
# Out:
# Text(0.5,0,'Relative Importance')

# %% [markdown]
# ### Scaling Data using Min-Max Scaler
#
# Use of MinMaxScaler because it doesn't change underlying structure of data. It just brings values between -1 and 1.
#
# Standardisation changes underlying structure of data by changing Mean and Standard deviation of variables.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %% [markdown]
# ## Lasso Regression (Feature Reduction)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
lasso = Lasso(max_iter = 10000).fit(X_train,y_train)
param_grid = {'alpha':[0.01, 1, 5, 10, 100]}
grid_search = GridSearchCV(lasso, param_grid, cv = 5)
grid_search.fit(X_train, y_train)
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Best parameters: {'alpha': 0.01}

# %%
lasso = Lasso(max_iter = 10000, alpha=0.01).fit(X_train,y_train)
print("Number of features used: {}".format(np.sum(lasso.coef_ != 0)))
print('Accuracy of Lasso Regressor on training set: {:.2f}'
     .format(lasso.score(X_train, y_train)))
print('Accuracy of Lasso Regressor on test set: {:.2f}'
     .format(lasso.score(X_test, y_test)))
# Out:
# Number of features used: 20
# Accuracy of Lasso Regressor on training set: 0.47
# Accuracy of Lasso Regressor on test set: 0.46

# %% [markdown]
# ### Low Accuracy on Both Training and test set. Not the Ideal Model

# %%
print('Features with non-zero weight (sorted by absolute magnitude):')
for e in sorted (list(zip(list(X1), lasso.coef_)),
                key = lambda e: -abs(e[1])):
    if e[1] != 0:
        print('\t{}, {:.3f}'.format(e[0], e[1]))
# Out:
# Features with non-zero weight (sorted by absolute magnitude):
# 	Number_of_Vehicles, 39.890
# 	Bus_or_Coach_Passenger, 3.127
# 	Accident_Severity, -2.591
# 	Casualty_Severity, 2.019
# 	Car_Passenger, 1.195
# 	Engine_Capacity_(CC), 0.874
# 	Speed_limit, 0.318
# 	Age_Band_of_Casualty, -0.273
# 	Did_Police_Officer_Attend_Scene_of_Accident, -0.250
# 	Weather_Conditions, 0.146
# 	Vehicle_Leaving_Carriageway, 0.108
# 	Time_of_Day, -0.104
# 	Urban_or_Rural_Area, 0.102
# 	Driver_IMD_Decile, -0.092
# 	Vehicle_Manoeuvre, 0.087
# 	Journey_Purpose_of_Driver, 0.077
# 	Casualty_Class, 0.035
# 	Day_of_Week, -0.016
# 	Light_Conditions, 0.008
# 	Driver_Home_Area_Type, -0.004

# %% [markdown]
# ### Lasso gives a very poor training and test score.

# %% [markdown]
# ## <font color='red'> New Data Set consiting of Top 20 Features

# %%
X= data2[["Number_of_Vehicles", "Accident_Severity", "Bus_or_Coach_Passenger", "Speed_limit", "Car_Passenger",
        "Light_Conditions", "Engine_Capacity_(CC)", "Vehicle_Leaving_Carriageway", "Time_of_Day"
        ,"Skidding_and_Overturning", "Casualty_Type", "Day_of_Week", "Age_Band_of_Casualty", "Local_Authority_(District)"
        ,"Police_Force", "Casualty_Class", "Vehicle_Manoeuvre", "Age_Band_of_Driver", "Casualty_Severity", "Driver_IMD_Decile"]]

# %%
X.columns
# Out:
# Index(['Number_of_Vehicles', 'Accident_Severity', 'Bus_or_Coach_Passenger',
#        'Speed_limit', 'Car_Passenger', 'Light_Conditions',
#        'Engine_Capacity_(CC)', 'Vehicle_Leaving_Carriageway', 'Time_of_Day',
#        'Skidding_and_Overturning', 'Casualty_Type', 'Day_of_Week',
#        'Age_Band_of_Casualty', 'Local_Authority_(District)', 'Police_Force',
#        'Casualty_Class', 'Vehicle_Manoeuvre', 'Age_Band_of_Driver',
#        'Casualty_Severity', 'Driver_IMD_Decile'],
#       dtype='object')

# %%
X.shape
# Out:
# (97612, 20)

# %%
X.head()
# Out:
#    Number_of_Vehicles  Accident_Severity  Bus_or_Coach_Passenger  Speed_limit  \
# 0                   1                  3                     0.0           30
# 1                   1                  3                     0.0           30
# 3                   2                  3                     0.0           30
# 4                   2                  3                     0.0           30
# 6                   2                  3                     0.0           30
#
#    Car_Passenger  Light_Conditions  Engine_Capacity_(CC)  \
# 0            0.0                 1                 124.0
# 1            0.0                 1                 124.0
# 3            0.0                 1                 124.0
# 4            0.0                 4                2494.0
# 6            0.0                 1                1099.0
#
#    Vehicle_Leaving_Carriageway  Time_of_Day  Skidding_and_Overturning  \
# 0                            0            2                       0.0
# ...

# %%
y=data2['Number_of_Casualties']

# %%
y.shape
# Out:
# (97612,)

# %% [markdown]
# ### Splitting Data

# %%
from sklearn.model_selection import train_test_split
X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 10)
print("X Train Shape : {}".format(X_train_org.shape))
print("X Test Shape : {}".format(X_test_org.shape))
print("y Train Shape : {}".format(y_train.shape))
print("y Test Shape : {}".format(y_test.shape))
# Out:
# X Train Shape : (73209, 20)
# X Test Shape : (24403, 20)
# y Train Shape : (73209,)
# y Test Shape : (24403,)

# %% [markdown]
# ### Data Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %% [markdown]
# ## Implementing other Regression Models and Ensembles

# %%
import warnings
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
warnings.filterwarnings('ignore')

# %%
num_instances = len(X)
models = []
models.append(('KNN', KNeighborsRegressor()))
models.append(('Linear Regression', LinearRegression()))
models.append(('Ridge', Ridge()))
# models.append(('SVR', SVR()))
models.append(('Bagging Regressor', BaggingRegressor()))
models.append(('Gradient Boosting', GradientBoostingRegressor()))
models.append(('Ada Boost Regressor', AdaBoostRegressor()))

# Evaluations
results = []
names = []
scoring = []

for name, model in models:
    # Fit the model
    model.fit(X_train, y_train)
    # Evaluate the model
    score = model.score(X_test, y_test)
    results.append(score)
    names.append(name)
    msg = "%s: %f" % (name, score)
    print(msg)
# Out:
# KNN: 0.700601
# Linear Regression: 0.484530
# Ridge: 0.485031
# Baggging Regressor: 0.750763
# Gradient Boosting: 0.729129
# Ada Boost Regressor: 0.547684

# %% [markdown]
# ### Best Machine Learning Model : - Bagging Regressor

# %% [markdown]
# Author : - Shaurya Trehan
